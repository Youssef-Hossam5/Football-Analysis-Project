# %% [markdown]
# ## Installing required libs like:
# - ultralytics for yolo model
# - robo flow for data

# %%
# !pip install ultralytics
# !pip install roboflow

# %% [markdown]
# # Importing the required libraries for training the model

# %%
from roboflow import Roboflow
from dotenv import load_dotenv
import os

# %%
load_dotenv()
Roboflow_api_key = os.getenv("Roboflow_API_KEY")

# %%
rf = Roboflow(api_key=Roboflow_api_key)
project = rf.workspace("roboflow-jvuqo").project("football-players-detection-3zvbc")
version = project.version(20)
dataset = version.download("yolov5")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# # Getting Dataset and moving it to the right place
# - Downloading the dataset from roboflow and moving it to the right place for training

# %%
dataset.location
# Out:
# 'd:\\ITI\\Intake46\\Deep Learning\\DL-AI46-SV\\Project\\Football Analysis Project\\FOOTBALL_ANALYSIS\\training\\football-players-detection-20'

# %%
import shutil

shutil.move('football-players-detection-20/train',
            'football-players-detection-20/football-players-detection-20/train'
            )

shutil.move('football-players-detection-20/test',
            'football-players-detection-20/football-players-detection-20/test'
            )

shutil.move('football-players-detection-20/valid',
            'football-players-detection-20/football-players-detection-20/valid'
            )

# %% [markdown]
# # Training

# %%
data_path = r"D:\ITI\Intake46\Deep Learning\DL-AI46-SV\DL-AI46-SV\FOOTBALL_ANALYSIS\training\football-players-detection-20\data.yaml"
# !yolo task=detect mode=train model=YOLO26l.pt data="{data_path}" epochs=100 imgsz=640
